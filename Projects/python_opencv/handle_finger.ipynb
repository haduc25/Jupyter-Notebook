# %%
""" Install Library - anaconda (terminal) => conda activate deep_learning
# !pip install opencv-python
# !pip install mediapipe
"""

# %%
"""_summary_
    File hand.py
    https://google.github.io/mediapipe/solutions/hands
"""

import cv2 as cv
import os
import time

import hand

# %%
pTime = 0
capture = cv.VideoCapture(1)

# folder path
folderPath = 'finger/imgFingers'

# read the folder
lst = os.listdir(folderPath)
lst_2 = []

# loop to get image in folder
for i in lst:
    # print(i)

    # Get source of image => Learning/Self/opencv/finger/imgFingers/1.png => 6.png
    print(f'{folderPath}/{i}')

    # add source to image
    image = cv.imread(f'{folderPath}/{i}')

    # add ma tran image va lst_2
    lst_2.append(image)

# checking length of array
print(len(lst_2))  # 6

# lay ra shape of image
print(lst_2[0].shape)  # (132, 109, 3)

print(lst)  # ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png']

# phát hiện ra bàn tay, detectionCon tạm hiểu là độ tin cậy tối thiểu
detector = hand.handDetector(detectionCon=1)

# list finger
fingerId = [4, 8, 12, 16, 20]
# Out:
# finger/imgFingers/1.png
# finger/imgFingers/2.png
# finger/imgFingers/3.png
# finger/imgFingers/4.png
# finger/imgFingers/5.png
# finger/imgFingers/6.png
# 6
# (132, 109, 3)
# ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png']

# %%
while True:
    ret, frame = capture.read()

    # find hands
    frame = detector.findHands(frame)

    # find Position | phát hiện vị trí và draw 20 điểm trên bàn tay ra
    lmList = detector.findPosition(frame, draw=False)

    print(lmList)

    # nếu có bàn tay
    if len(lmList) != 0:
        # create a array empty
        fingers = []

        # ngón cái [4] - Kiểm tra xem [4] nằm bên trái hay bên phải điểm [3]
        # - lmList[fingerId[0]][1] - [0] là pt thứ 0 trong fingerId
        # - [1] là pt thứ 1 trong video input => trái, phải
        # - lmList[fingerId[0] - 1][1] - fingerId[0] - 1: kiểm tra ngón cái với điểm số 3 / 4 - 1 = 3 (đốt thứ 3)
        if lmList[fingerId[0]][1] < lmList[fingerId[0] - 1][1]:
            print('Ngón___đang mở', id)
            fingers.append(1)

            # show ngón đang mở
            print('Giá trị của ngón đang mở: ', lmList[fingerId[0]][1])
            print('Giá trị của đốt ngón đang mở: ',
                  lmList[fingerId[0] - 1][1])
        else:
            fingers.append(0)

        # loop from 1 -> 5 (8, 12, 16, 20) / because array have 4 index
        for id in range(1, 5):
            print('id: ', id)

            # ngón trỏ - [8][2] - 8 là dốt ngón tay thứ 8, 2 là phần tử thứ 2 => 0, 1, 2 | 2 là chiều cao (cao, thấp)
            # Logic: ngón nào đang mở thì thêm vào array 'fingers' 1 - ngược lại thêm 0
            if lmList[fingerId[id]][2] < lmList[fingerId[id] - 2][2]:
                print('Ngón___đang mở', id)
                fingers.append(1)

                # show ngón đang mở
                print('Giá trị của ngón đang mở: ', lmList[fingerId[id]][2])
                print('Giá trị của đốt ngón đang mở: ',
                      lmList[fingerId[id] - 2][2])
            else:
                fingers.append(0)

        print(f'Array fingers is {fingers}')
        countFingers = fingers.count(1)
        print('Số ngón tay đang mở: ', countFingers)

        # for first finger

        # save value image[0] shape
        """
        Image: ['1.png', '2.png', '3.png', '4.png', '5.png', '6.png']
        0 -> 5
        countFingers - 1 =>
            - mặc định là -1 => image cuối cùng => k ngón
            - nếu giơ 1 ngón => countFingers = 1 - 1 => 0 => image => 1.png => 1 ngón
            ... (tương tự đến hết)
        """
        height, width, channel = lst_2[countFingers - 1].shape

        # gán dl vào frame / gán image vào frame  | lấy 1 vùng trong Frame or Image => gán vùng = image ngón tay
        frame[0:height, 0:width] = lst_2[countFingers - 1]  # (132, 109, 3)

        # vẽ hình chữ nhật hiện số ngón tay
        cv.rectangle(frame, (0, 200), (150, 400), (0, 255, 0), -1)

        # add text
        cv.putText(frame, str(countFingers), (0, 390),
                   cv.FONT_HERSHEY_COMPLEX, 8, (255, 0, 0), 10)

    # show FPS | time.time() => trả về số giây, tính từ 0:0:00 ngày 1/1/1970 theo giờ UTC , gọi là (thời điểm bắt đầu thời gian)
    cTime = time.time()
    # 1 chia (thời gian hiện tại - thời gian ban đầu) | Tính FPS Frames per second - đây là  chỉ số khung hình trên mỗi giây
    fps = 1/(cTime-pTime)

    # gán lại để chạy lại vòng mới
    pTime = cTime

    # print(fps)
    # print(type(fps))  # float

    # display FPS on screen | putText
    cv.putText(frame, f'FPS: {int(fps)}', (150, 70),
               cv.FONT_HERSHEY_COMPLEX, 1.8, (0, 255, 0), 3)

    # gán dl vào frame / gán image vào frame
    # frame[0:height, 0:width] = lst_2[0]  # (132, 109, 3)

    cv.imshow('Window capture', frame)

    if cv.waitKey(1) == ord('q'):
        break

capture.release()
cv.destroyAllWindows()
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[0, 565, 531], [1, 472, 514], [2, 393, 467], [3, 345, 410], [4, 324, 351], [5, 404, 397], [6, 375, 316], [7, 360, 272], [8, 347, 234], [9, 451, 375], [10, 421, 285], [11, 403, 233], [12, 384, 190], [13, 505, 364], [14, 474, 283], [15, 457, 230], [16, 439, 186], [17, 562, 362], [18, 539, 301], [19, 521, 261], [20, 502, 225]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  324
# Giá trị của đốt ngón đang mở:  345
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  234
# Giá trị của đốt ngón đang mở:  316
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  190
# Giá trị của đốt ngón đang mở:  285
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  186
# Giá trị của đốt ngón đang mở:  283
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  225
# Giá trị của đốt ngón đang mở:  301
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 514, 546], [1, 428, 522], [2, 360, 467], [3, 326, 406], [4, 299, 353], [5, 391, 380], [6, 356, 306], [7, 334, 262], [8, 315, 222], [9, 434, 359], [10, 396, 278], [11, 370, 226], [12, 346, 183], [13, 481, 353], [14, 446, 272], [15, 424, 220], [16, 403, 175], [17, 533, 357], [18, 505, 293], [19, 484, 251], [20, 463, 215]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  299
# Giá trị của đốt ngón đang mở:  326
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  222
# Giá trị của đốt ngón đang mở:  306
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  183
# Giá trị của đốt ngón đang mở:  278
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  175
# Giá trị của đốt ngón đang mở:  272
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  215
# Giá trị của đốt ngón đang mở:  293
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 468, 507], [1, 371, 476], [2, 308, 422], [3, 273, 369], [4, 239, 327], [5, 343, 326], [6, 310, 264], [7, 289, 225], [8, 270, 186], [9, 380, 303], [10, 347, 233], [11, 321, 187], [12, 298, 145], [13, 418, 296], [14, 393, 227], [15, 373, 182], [16, 350, 139], [17, 464, 303], [18, 445, 245], [19, 427, 208], [20, 407, 171]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  239
# Giá trị của đốt ngón đang mở:  273
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  186
# Giá trị của đốt ngón đang mở:  264
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  145
# Giá trị của đốt ngón đang mở:  233
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  139
# Giá trị của đốt ngón đang mở:  227
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  171
# Giá trị của đốt ngón đang mở:  245
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 457, 495], [1, 369, 472], [2, 309, 420], [3, 276, 367], [4, 243, 328], [5, 343, 324], [6, 310, 262], [7, 288, 226], [8, 270, 190], [9, 380, 303], [10, 345, 230], [11, 320, 185], [12, 298, 145], [13, 419, 297], [14, 392, 223], [15, 371, 178], [16, 349, 135], [17, 465, 304], [18, 446, 243], [19, 427, 206], [20, 407, 171]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  243
# Giá trị của đốt ngón đang mở:  276
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  190
# Giá trị của đốt ngón đang mở:  262
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  145
# Giá trị của đốt ngón đang mở:  230
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  135
# Giá trị của đốt ngón đang mở:  223
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  171
# Giá trị của đốt ngón đang mở:  243
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 428, 454], [1, 339, 437], [2, 273, 381], [3, 236, 335], [4, 200, 312], [5, 311, 284], [6, 277, 224], [7, 255, 187], [8, 236, 153], [9, 347, 261], [10, 315, 189], [11, 290, 144], [12, 269, 108], [13, 386, 255], [14, 362, 182], [15, 345, 137], [16, 328, 97], [17, 428, 261], [18, 415, 202], [19, 402, 165], [20, 388, 129]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  200
# Giá trị của đốt ngón đang mở:  236
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  153
# Giá trị của đốt ngón đang mở:  224
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  189
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  97
# Giá trị của đốt ngón đang mở:  182
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  129
# Giá trị của đốt ngón đang mở:  202
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 429, 448], [1, 342, 431], [2, 277, 378], [3, 237, 333], [4, 201, 310], [5, 312, 282], [6, 278, 222], [7, 257, 186], [8, 240, 152], [9, 348, 260], [10, 315, 188], [11, 291, 143], [12, 270, 106], [13, 387, 252], [14, 362, 178], [15, 344, 133], [16, 324, 93], [17, 430, 256], [18, 416, 196], [19, 402, 158], [20, 387, 122]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  201
# Giá trị của đốt ngón đang mở:  237
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  152
# Giá trị của đốt ngón đang mở:  222
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  106
# Giá trị của đốt ngón đang mở:  188
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  93
# Giá trị của đốt ngón đang mở:  178
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  122
# Giá trị của đốt ngón đang mở:  196
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 441, 432], [1, 354, 421], [2, 283, 371], [3, 241, 328], [4, 204, 309], [5, 314, 269], [6, 278, 211], [7, 257, 175], [8, 240, 142], [9, 350, 248], [10, 315, 176], [11, 292, 132], [12, 272, 96], [13, 389, 241], [14, 365, 167], [15, 348, 122], [16, 331, 84], [17, 431, 245], [18, 421, 185], [19, 410, 147], [20, 398, 111]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  204
# Giá trị của đốt ngón đang mở:  241
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  142
# Giá trị của đốt ngón đang mở:  211
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  96
# Giá trị của đốt ngón đang mở:  176
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  84
# Giá trị của đốt ngón đang mở:  167
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  111
# Giá trị của đốt ngón đang mở:  185
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 441, 426], [1, 355, 414], [2, 283, 365], [3, 238, 326], [4, 201, 311], [5, 314, 266], [6, 278, 207], [7, 257, 170], [8, 239, 137], [9, 349, 243], [10, 315, 171], [11, 291, 127], [12, 270, 91], [13, 388, 235], [14, 365, 160], [15, 347, 114], [16, 329, 74], [17, 431, 239], [18, 422, 179], [19, 412, 140], [20, 400, 103]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  201
# Giá trị của đốt ngón đang mở:  238
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  137
# Giá trị của đốt ngón đang mở:  207
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  91
# Giá trị của đốt ngón đang mở:  171
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  74
# Giá trị của đốt ngón đang mở:  160
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  103
# Giá trị của đốt ngón đang mở:  179
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 424, 418], [1, 338, 409], [2, 261, 360], [3, 213, 321], [4, 174, 310], [5, 296, 253], [6, 262, 192], [7, 240, 155], [8, 224, 123], [9, 334, 231], [10, 300, 157], [11, 278, 111], [12, 259, 75], [13, 374, 225], [14, 353, 149], [15, 338, 103], [16, 323, 64], [17, 418, 230], [18, 414, 169], [19, 405, 129], [20, 395, 91]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  174
# Giá trị của đốt ngón đang mở:  213
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  123
# Giá trị của đốt ngón đang mở:  192
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  75
# Giá trị của đốt ngón đang mở:  157
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  64
# Giá trị của đốt ngón đang mở:  149
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  91
# Giá trị của đốt ngón đang mở:  169
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 416, 419], [1, 329, 407], [2, 253, 358], [3, 203, 321], [4, 164, 310], [5, 289, 250], [6, 252, 187], [7, 230, 148], [8, 212, 115], [9, 327, 228], [10, 293, 151], [11, 270, 104], [12, 250, 67], [13, 368, 222], [14, 346, 144], [15, 331, 96], [16, 316, 55], [17, 413, 228], [18, 409, 166], [19, 402, 125], [20, 394, 87]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  164
# Giá trị của đốt ngón đang mở:  203
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  115
# Giá trị của đốt ngón đang mở:  187
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  67
# Giá trị của đốt ngón đang mở:  151
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  55
# Giá trị của đốt ngón đang mở:  144
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  87
# Giá trị của đốt ngón đang mở:  166
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 402, 410], [1, 316, 400], [2, 238, 356], [3, 187, 323], [4, 149, 313], [5, 270, 243], [6, 231, 180], [7, 207, 142], [8, 187, 109], [9, 309, 220], [10, 271, 142], [11, 244, 92], [12, 223, 53], [13, 351, 213], [14, 326, 134], [15, 310, 84], [16, 295, 43], [17, 398, 219], [18, 393, 153], [19, 387, 109], [20, 378, 68]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  149
# Giá trị của đốt ngón đang mở:  187
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  109
# Giá trị của đốt ngón đang mở:  180
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  53
# Giá trị của đốt ngón đang mở:  142
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  43
# Giá trị của đốt ngón đang mở:  134
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  68
# Giá trị của đốt ngón đang mở:  153
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 411, 393], [1, 327, 386], [2, 251, 346], [3, 200, 316], [4, 160, 309], [5, 272, 234], [6, 227, 177], [7, 199, 142], [8, 176, 111], [9, 306, 208], [10, 260, 134], [11, 231, 87], [12, 207, 50], [13, 348, 198], [14, 317, 120], [15, 296, 71], [16, 277, 29], [17, 395, 201], [18, 392, 135], [19, 388, 91], [20, 383, 50]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  160
# Giá trị của đốt ngón đang mở:  200
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  111
# Giá trị của đốt ngón đang mở:  177
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  50
# Giá trị của đốt ngón đang mở:  134
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  29
# Giá trị của đốt ngón đang mở:  120
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  50
# Giá trị của đốt ngón đang mở:  135
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 418, 377], [1, 337, 373], [2, 264, 338], [3, 214, 309], [4, 175, 299], [5, 279, 226], [6, 233, 171], [7, 204, 138], [8, 181, 108], [9, 310, 200], [10, 264, 128], [11, 233, 84], [12, 207, 49], [13, 350, 188], [14, 319, 111], [15, 299, 64], [16, 281, 25], [17, 397, 189], [18, 395, 124], [19, 390, 80], [20, 384, 40]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  175
# Giá trị của đốt ngón đang mở:  214
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  171
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  49
# Giá trị của đốt ngón đang mở:  128
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  25
# Giá trị của đốt ngón đang mở:  111
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  40
# Giá trị của đốt ngón đang mở:  124
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 418, 375], [1, 339, 370], [2, 265, 336], [3, 216, 308], [4, 177, 299], [5, 280, 226], [6, 235, 170], [7, 206, 137], [8, 183, 108], [9, 312, 199], [10, 267, 128], [11, 236, 84], [12, 211, 49], [13, 352, 187], [14, 320, 112], [15, 299, 65], [16, 279, 26], [17, 397, 188], [18, 392, 125], [19, 385, 82], [20, 377, 43]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  177
# Giá trị của đốt ngón đang mở:  216
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  170
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  49
# Giá trị của đốt ngón đang mở:  128
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  26
# Giá trị của đốt ngón đang mở:  112
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  43
# Giá trị của đốt ngón đang mở:  125
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 417, 371], [1, 338, 367], [2, 265, 334], [3, 216, 307], [4, 177, 297], [5, 280, 225], [6, 235, 169], [7, 206, 136], [8, 182, 107], [9, 311, 198], [10, 265, 128], [11, 234, 84], [12, 209, 48], [13, 350, 186], [14, 318, 112], [15, 296, 65], [16, 276, 26], [17, 396, 186], [18, 390, 123], [19, 383, 81], [20, 374, 42]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  177
# Giá trị của đốt ngón đang mở:  216
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  107
# Giá trị của đốt ngón đang mở:  169
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  48
# Giá trị của đốt ngón đang mở:  128
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  26
# Giá trị của đốt ngón đang mở:  112
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  42
# Giá trị của đốt ngón đang mở:  123
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 412, 365], [1, 334, 362], [2, 261, 328], [3, 213, 301], [4, 175, 293], [5, 278, 222], [6, 235, 168], [7, 207, 135], [8, 184, 107], [9, 309, 196], [10, 264, 127], [11, 234, 83], [12, 209, 49], [13, 348, 185], [14, 316, 112], [15, 295, 66], [16, 275, 28], [17, 392, 185], [18, 388, 123], [19, 381, 81], [20, 373, 42]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  175
# Giá trị của đốt ngón đang mở:  213
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  107
# Giá trị của đốt ngón đang mở:  168
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  49
# Giá trị của đốt ngón đang mở:  127
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  28
# Giá trị của đốt ngón đang mở:  112
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  42
# Giá trị của đốt ngón đang mở:  123
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 410, 365], [1, 333, 362], [2, 263, 328], [3, 215, 302], [4, 178, 292], [5, 279, 221], [6, 236, 167], [7, 208, 135], [8, 185, 107], [9, 310, 196], [10, 265, 127], [11, 235, 84], [12, 209, 49], [13, 348, 185], [14, 317, 111], [15, 297, 66], [16, 278, 28], [17, 392, 186], [18, 387, 123], [19, 381, 81], [20, 373, 42]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  178
# Giá trị của đốt ngón đang mở:  215
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  107
# Giá trị của đốt ngón đang mở:  167
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  49
# Giá trị của đốt ngón đang mở:  127
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  28
# Giá trị của đốt ngón đang mở:  111
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  42
# Giá trị của đốt ngón đang mở:  123
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 411, 361], [1, 335, 360], [2, 265, 326], [3, 218, 299], [4, 180, 289], [5, 281, 220], [6, 238, 167], [7, 211, 135], [8, 189, 107], [9, 312, 195], [10, 267, 127], [11, 237, 84], [12, 213, 50], [13, 350, 184], [14, 318, 111], [15, 298, 66], [16, 280, 28], [17, 393, 184], [18, 389, 122], [19, 382, 81], [20, 375, 42]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  180
# Giá trị của đốt ngón đang mở:  218
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  107
# Giá trị của đốt ngón đang mở:  167
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  50
# Giá trị của đốt ngón đang mở:  127
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  28
# Giá trị của đốt ngón đang mở:  111
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  42
# Giá trị của đốt ngón đang mở:  122
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 410, 360], [1, 333, 358], [2, 262, 326], [3, 214, 299], [4, 178, 290], [5, 280, 220], [6, 237, 166], [7, 209, 133], [8, 187, 104], [9, 310, 194], [10, 265, 126], [11, 234, 82], [12, 209, 47], [13, 349, 183], [14, 318, 111], [15, 297, 65], [16, 278, 27], [17, 392, 184], [18, 388, 122], [19, 381, 79], [20, 373, 40]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  178
# Giá trị của đốt ngón đang mở:  214
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  104
# Giá trị của đốt ngón đang mở:  166
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  47
# Giá trị của đốt ngón đang mở:  126
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  27
# Giá trị của đốt ngón đang mở:  111
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  40
# Giá trị của đốt ngón đang mở:  122
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 409, 360], [1, 332, 358], [2, 261, 325], [3, 213, 298], [4, 177, 290], [5, 279, 218], [6, 235, 165], [7, 208, 133], [8, 185, 104], [9, 309, 193], [10, 264, 125], [11, 234, 81], [12, 209, 47], [13, 348, 182], [14, 317, 109], [15, 297, 64], [16, 278, 25], [17, 391, 184], [18, 386, 121], [19, 380, 79], [20, 372, 40]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  177
# Giá trị của đốt ngón đang mở:  213
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  104
# Giá trị của đốt ngón đang mở:  165
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  47
# Giá trị của đốt ngón đang mở:  125
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  25
# Giá trị của đốt ngón đang mở:  109
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  40
# Giá trị của đốt ngón đang mở:  121
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 409, 360], [1, 332, 358], [2, 261, 325], [3, 213, 298], [4, 176, 290], [5, 279, 218], [6, 236, 164], [7, 208, 132], [8, 186, 103], [9, 309, 193], [10, 265, 124], [11, 234, 81], [12, 209, 46], [13, 348, 182], [14, 317, 108], [15, 297, 63], [16, 278, 24], [17, 391, 183], [18, 386, 121], [19, 380, 79], [20, 372, 39]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  176
# Giá trị của đốt ngón đang mở:  213
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  103
# Giá trị của đốt ngón đang mở:  164
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  46
# Giá trị của đốt ngón đang mở:  124
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  24
# Giá trị của đốt ngón đang mở:  108
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  39
# Giá trị của đốt ngón đang mở:  121
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 409, 357], [1, 332, 356], [2, 262, 322], [3, 215, 294], [4, 177, 286], [5, 281, 216], [6, 239, 163], [7, 211, 131], [8, 189, 102], [9, 311, 191], [10, 267, 123], [11, 236, 80], [12, 211, 45], [13, 349, 180], [14, 319, 106], [15, 299, 62], [16, 280, 24], [17, 393, 181], [18, 390, 119], [19, 383, 77], [20, 375, 37]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  177
# Giá trị của đốt ngón đang mở:  215
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  102
# Giá trị của đốt ngón đang mở:  163
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  45
# Giá trị của đốt ngón đang mở:  123
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  24
# Giá trị của đốt ngón đang mở:  106
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  37
# Giá trị của đốt ngón đang mở:  119
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 411, 354], [1, 334, 352], [2, 264, 317], [3, 217, 289], [4, 179, 282], [5, 284, 212], [6, 243, 159], [7, 216, 127], [8, 193, 98], [9, 315, 187], [10, 271, 119], [11, 240, 76], [12, 214, 41], [13, 353, 177], [14, 324, 103], [15, 304, 58], [16, 285, 20], [17, 397, 179], [18, 394, 116], [19, 388, 73], [20, 380, 34]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  179
# Giá trị của đốt ngón đang mở:  217
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  98
# Giá trị của đốt ngón đang mở:  159
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  41
# Giá trị của đốt ngón đang mở:  119
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  20
# Giá trị của đốt ngón đang mở:  103
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  34
# Giá trị của đốt ngón đang mở:  116
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 412, 352], [1, 335, 350], [2, 265, 315], [3, 217, 288], [4, 180, 280], [5, 284, 210], [6, 242, 155], [7, 215, 123], [8, 192, 94], [9, 315, 185], [10, 271, 115], [11, 240, 71], [12, 214, 37], [13, 353, 175], [14, 324, 100], [15, 303, 54], [16, 283, 16], [17, 397, 177], [18, 395, 114], [19, 389, 71], [20, 381, 31]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  180
# Giá trị của đốt ngón đang mở:  217
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  94
# Giá trị của đốt ngón đang mở:  155
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  37
# Giá trị của đốt ngón đang mở:  115
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  16
# Giá trị của đốt ngón đang mở:  100
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  31
# Giá trị của đốt ngón đang mở:  114
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 412, 352], [1, 335, 350], [2, 265, 316], [3, 217, 289], [4, 181, 280], [5, 284, 210], [6, 242, 155], [7, 215, 123], [8, 192, 94], [9, 316, 185], [10, 272, 115], [11, 241, 71], [12, 216, 36], [13, 354, 174], [14, 324, 99], [15, 305, 53], [16, 286, 14], [17, 398, 176], [18, 394, 113], [19, 388, 69], [20, 381, 29]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  181
# Giá trị của đốt ngón đang mở:  217
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  94
# Giá trị của đốt ngón đang mở:  155
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  36
# Giá trị của đốt ngón đang mở:  115
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  14
# Giá trị của đốt ngón đang mở:  99
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  29
# Giá trị của đốt ngón đang mở:  113
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 411, 352], [1, 335, 350], [2, 266, 316], [3, 219, 288], [4, 182, 279], [5, 286, 209], [6, 244, 156], [7, 217, 123], [8, 194, 94], [9, 316, 184], [10, 272, 115], [11, 242, 72], [12, 217, 37], [13, 355, 174], [14, 325, 99], [15, 305, 54], [16, 287, 15], [17, 398, 176], [18, 395, 114], [19, 390, 71], [20, 382, 32]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  182
# Giá trị của đốt ngón đang mở:  219
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  94
# Giá trị của đốt ngón đang mở:  156
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  37
# Giá trị của đốt ngón đang mở:  115
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  15
# Giá trị của đốt ngón đang mở:  99
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  32
# Giá trị của đốt ngón đang mở:  114
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 411, 354], [1, 335, 352], [2, 266, 319], [3, 218, 292], [4, 181, 281], [5, 285, 212], [6, 241, 157], [7, 213, 124], [8, 191, 95], [9, 316, 187], [10, 272, 116], [11, 241, 72], [12, 216, 36], [13, 355, 177], [14, 325, 102], [15, 305, 56], [16, 286, 17], [17, 398, 179], [18, 395, 116], [19, 389, 72], [20, 381, 32]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  181
# Giá trị của đốt ngón đang mở:  218
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  95
# Giá trị của đốt ngón đang mở:  157
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  36
# Giá trị của đốt ngón đang mở:  116
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  17
# Giá trị của đốt ngón đang mở:  102
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  32
# Giá trị của đốt ngón đang mở:  116
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 412, 355], [1, 336, 352], [2, 266, 319], [3, 218, 291], [4, 181, 280], [5, 284, 211], [6, 242, 156], [7, 215, 124], [8, 192, 94], [9, 315, 187], [10, 271, 116], [11, 241, 72], [12, 216, 37], [13, 354, 177], [14, 325, 102], [15, 306, 56], [16, 288, 16], [17, 398, 180], [18, 395, 117], [19, 389, 75], [20, 381, 35]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  181
# Giá trị của đốt ngón đang mở:  218
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  94
# Giá trị của đốt ngón đang mở:  156
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  37
# Giá trị của đốt ngón đang mở:  116
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  16
# Giá trị của đốt ngón đang mở:  102
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  35
# Giá trị của đốt ngón đang mở:  117
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 412, 354], [1, 335, 351], [2, 266, 317], [3, 219, 289], [4, 182, 279], [5, 284, 211], [6, 243, 156], [7, 216, 123], [8, 193, 94], [9, 315, 186], [10, 272, 116], [11, 242, 72], [12, 217, 36], [13, 354, 176], [14, 325, 101], [15, 306, 55], [16, 289, 16], [17, 398, 179], [18, 395, 116], [19, 389, 74], [20, 381, 35]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  182
# Giá trị của đốt ngón đang mở:  219
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  94
# Giá trị của đốt ngón đang mở:  156
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  36
# Giá trị của đốt ngón đang mở:  116
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  16
# Giá trị của đốt ngón đang mở:  101
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  35
# Giá trị của đốt ngón đang mở:  116
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 410, 352], [1, 333, 348], [2, 265, 315], [3, 219, 286], [4, 182, 274], [5, 283, 208], [6, 242, 153], [7, 214, 120], [8, 192, 91], [9, 315, 183], [10, 271, 113], [11, 240, 69], [12, 214, 34], [13, 353, 173], [14, 325, 99], [15, 305, 53], [16, 286, 14], [17, 398, 176], [18, 395, 114], [19, 389, 72], [20, 380, 33]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  182
# Giá trị của đốt ngón đang mở:  219
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  91
# Giá trị của đốt ngón đang mở:  153
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  34
# Giá trị của đốt ngón đang mở:  113
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  14
# Giá trị của đốt ngón đang mở:  99
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  33
# Giá trị của đốt ngón đang mở:  114
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 408, 352], [1, 332, 348], [2, 263, 315], [3, 216, 287], [4, 179, 275], [5, 282, 208], [6, 240, 152], [7, 213, 119], [8, 190, 89], [9, 314, 183], [10, 270, 112], [11, 239, 67], [12, 213, 31], [13, 353, 173], [14, 324, 99], [15, 305, 53], [16, 286, 14], [17, 397, 176], [18, 394, 114], [19, 387, 72], [20, 378, 34]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  179
# Giá trị của đốt ngón đang mở:  216
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  89
# Giá trị của đốt ngón đang mở:  152
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  31
# Giá trị của đốt ngón đang mở:  112
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  14
# Giá trị của đốt ngón đang mở:  99
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  34
# Giá trị của đốt ngón đang mở:  114
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 400, 352], [1, 323, 350], [2, 252, 318], [3, 204, 289], [4, 166, 278], [5, 273, 212], [6, 230, 157], [7, 203, 124], [8, 182, 94], [9, 306, 187], [10, 264, 117], [11, 235, 73], [12, 212, 37], [13, 345, 176], [14, 315, 103], [15, 296, 59], [16, 277, 21], [17, 390, 178], [18, 385, 118], [19, 377, 77], [20, 367, 39]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  166
# Giá trị của đốt ngón đang mở:  204
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  94
# Giá trị của đốt ngón đang mở:  157
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  37
# Giá trị của đốt ngón đang mở:  117
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  21
# Giá trị của đốt ngón đang mở:  103
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  39
# Giá trị của đốt ngón đang mở:  118
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 379, 347], [1, 297, 345], [2, 226, 322], [3, 177, 294], [4, 141, 282], [5, 253, 219], [6, 216, 164], [7, 196, 129], [8, 179, 98], [9, 288, 194], [10, 252, 125], [11, 229, 82], [12, 210, 47], [13, 326, 184], [14, 301, 115], [15, 286, 71], [16, 273, 34], [17, 370, 187], [18, 365, 131], [19, 358, 94], [20, 350, 60]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  141
# Giá trị của đốt ngón đang mở:  177
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  98
# Giá trị của đốt ngón đang mở:  164
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  47
# Giá trị của đốt ngón đang mở:  125
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  34
# Giá trị của đốt ngón đang mở:  115
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  60
# Giá trị của đốt ngón đang mở:  131
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 378, 345], [1, 298, 346], [2, 228, 323], [3, 179, 298], [4, 144, 284], [5, 256, 219], [6, 219, 164], [7, 197, 129], [8, 181, 97], [9, 290, 195], [10, 253, 127], [11, 229, 85], [12, 211, 49], [13, 328, 185], [14, 304, 115], [15, 287, 72], [16, 273, 36], [17, 371, 188], [18, 367, 131], [19, 360, 96], [20, 350, 64]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  144
# Giá trị của đốt ngón đang mở:  179
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  97
# Giá trị của đốt ngón đang mở:  164
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  49
# Giá trị của đốt ngón đang mở:  127
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  36
# Giá trị của đốt ngón đang mở:  115
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  64
# Giá trị của đốt ngón đang mở:  131
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 363, 342], [1, 284, 337], [2, 207, 323], [3, 150, 303], [4, 114, 281], [5, 213, 244], [6, 179, 188], [7, 169, 153], [8, 162, 121], [9, 245, 222], [10, 216, 159], [11, 206, 118], [12, 200, 81], [13, 279, 211], [14, 260, 151], [15, 254, 111], [16, 252, 78], [17, 318, 210], [18, 308, 165], [19, 305, 137], [20, 304, 112]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  114
# Giá trị của đốt ngón đang mở:  150
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  121
# Giá trị của đốt ngón đang mở:  188
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  81
# Giá trị của đốt ngón đang mở:  159
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  78
# Giá trị của đốt ngón đang mở:  151
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  112
# Giá trị của đốt ngón đang mở:  165
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 349, 345], [1, 313, 282], [2, 251, 254], [3, 210, 237], [4, 188, 210], [5, 187, 269], [6, 160, 203], [7, 155, 152], [8, 157, 114], [9, 190, 270], [10, 166, 197], [11, 168, 143], [12, 175, 98], [13, 205, 267], [14, 174, 205], [15, 171, 154], [16, 176, 113], [17, 229, 264], [18, 191, 234], [19, 174, 204], [20, 167, 178]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  188
# Giá trị của đốt ngón đang mở:  210
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  114
# Giá trị của đốt ngón đang mở:  203
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  98
# Giá trị của đốt ngón đang mở:  197
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  113
# Giá trị của đốt ngón đang mở:  205
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  178
# Giá trị của đốt ngón đang mở:  234
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 329, 352], [1, 350, 281], [2, 311, 219], [3, 267, 173], [4, 233, 124], [5, 222, 235], [6, 160, 161], [7, 144, 114], [8, 140, 81], [9, 202, 256], [10, 146, 181], [11, 140, 134], [12, 149, 103], [13, 197, 266], [14, 149, 201], [15, 144, 160], [16, 147, 129], [17, 201, 266], [18, 159, 213], [19, 149, 176], [20, 149, 148]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  233
# Giá trị của đốt ngón đang mở:  267
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  81
# Giá trị của đốt ngón đang mở:  161
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  103
# Giá trị của đốt ngón đang mở:  181
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  129
# Giá trị của đốt ngón đang mở:  201
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  148
# Giá trị của đốt ngón đang mở:  213
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 334, 351], [1, 356, 278], [2, 324, 212], [3, 281, 156], [4, 247, 106], [5, 231, 227], [6, 172, 153], [7, 149, 110], [8, 136, 79], [9, 207, 253], [10, 152, 179], [11, 138, 134], [12, 137, 106], [13, 201, 272], [14, 151, 216], [15, 136, 178], [16, 128, 150], [17, 207, 280], [18, 165, 240], [19, 150, 211], [20, 144, 189]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  247
# Giá trị của đốt ngón đang mở:  281
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  79
# Giá trị của đốt ngón đang mở:  153
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  106
# Giá trị của đốt ngón đang mở:  179
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  150
# Giá trị của đốt ngón đang mở:  216
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  189
# Giá trị của đốt ngón đang mở:  240
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 332, 352], [1, 355, 277], [2, 323, 211], [3, 281, 156], [4, 247, 106], [5, 230, 226], [6, 172, 155], [7, 148, 111], [8, 134, 81], [9, 206, 251], [10, 153, 180], [11, 139, 136], [12, 137, 108], [13, 201, 270], [14, 153, 217], [15, 137, 180], [16, 130, 153], [17, 208, 281], [18, 169, 243], [19, 152, 216], [20, 146, 195]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  247
# Giá trị của đốt ngón đang mở:  281
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  81
# Giá trị của đốt ngón đang mở:  155
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  180
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  153
# Giá trị của đốt ngón đang mở:  217
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  195
# Giá trị của đốt ngón đang mở:  243
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 332, 352], [1, 355, 278], [2, 324, 212], [3, 283, 158], [4, 248, 108], [5, 229, 225], [6, 172, 154], [7, 147, 111], [8, 133, 81], [9, 206, 251], [10, 154, 180], [11, 141, 135], [12, 139, 108], [13, 201, 271], [14, 153, 218], [15, 136, 180], [16, 128, 153], [17, 208, 281], [18, 169, 243], [19, 153, 215], [20, 147, 195]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  248
# Giá trị của đốt ngón đang mở:  283
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  81
# Giá trị của đốt ngón đang mở:  154
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  180
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  153
# Giá trị của đốt ngón đang mở:  218
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  195
# Giá trị của đốt ngón đang mở:  243
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 334, 352], [1, 355, 278], [2, 325, 210], [3, 286, 154], [4, 255, 103], [5, 231, 221], [6, 177, 151], [7, 152, 111], [8, 138, 83], [9, 208, 247], [10, 158, 177], [11, 140, 134], [12, 133, 108], [13, 203, 268], [14, 154, 222], [15, 130, 189], [16, 114, 163], [17, 211, 282], [18, 174, 254], [19, 157, 234], [20, 149, 220]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  255
# Giá trị của đốt ngón đang mở:  286
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  83
# Giá trị của đốt ngón đang mở:  151
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  177
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  163
# Giá trị của đốt ngón đang mở:  222
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  220
# Giá trị của đốt ngón đang mở:  254
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 334, 353], [1, 355, 279], [2, 326, 211], [3, 288, 156], [4, 257, 105], [5, 232, 223], [6, 178, 153], [7, 151, 112], [8, 135, 82], [9, 210, 248], [10, 158, 181], [11, 138, 138], [12, 130, 111], [13, 205, 270], [14, 155, 225], [15, 129, 193], [16, 112, 169], [17, 212, 284], [18, 175, 254], [19, 158, 235], [20, 148, 220]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  257
# Giá trị của đốt ngón đang mở:  288
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  82
# Giá trị của đốt ngón đang mở:  153
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  111
# Giá trị của đốt ngón đang mở:  181
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  169
# Giá trị của đốt ngón đang mở:  225
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  220
# Giá trị của đốt ngón đang mở:  254
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 346, 343], [1, 369, 270], [2, 348, 202], [3, 314, 145], [4, 288, 96], [5, 253, 210], [6, 207, 141], [7, 181, 101], [8, 162, 73], [9, 229, 236], [10, 178, 173], [11, 152, 136], [12, 137, 114], [13, 222, 261], [14, 170, 220], [15, 138, 193], [16, 112, 174], [17, 227, 281], [18, 187, 265], [19, 162, 256], [20, 141, 253]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  288
# Giá trị của đốt ngón đang mở:  314
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  73
# Giá trị của đốt ngón đang mở:  141
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  114
# Giá trị của đốt ngón đang mở:  173
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  174
# Giá trị của đốt ngón đang mở:  220
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  253
# Giá trị của đốt ngón đang mở:  265
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 353, 335], [1, 379, 263], [2, 358, 197], [3, 326, 138], [4, 302, 88], [5, 266, 203], [6, 219, 135], [7, 193, 96], [8, 175, 69], [9, 240, 229], [10, 190, 165], [11, 164, 128], [12, 146, 105], [13, 230, 253], [14, 178, 212], [15, 146, 187], [16, 119, 168], [17, 232, 274], [18, 194, 261], [19, 168, 254], [20, 148, 250]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  302
# Giá trị của đốt ngón đang mở:  326
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  69
# Giá trị của đốt ngón đang mở:  135
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  105
# Giá trị của đốt ngón đang mở:  165
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  168
# Giá trị của đốt ngón đang mở:  212
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  250
# Giá trị của đốt ngón đang mở:  261
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 364, 329], [1, 389, 258], [2, 370, 192], [3, 339, 135], [4, 317, 88], [5, 280, 201], [6, 234, 133], [7, 210, 95], [8, 192, 66], [9, 254, 226], [10, 205, 163], [11, 177, 126], [12, 156, 100], [13, 243, 251], [14, 191, 210], [15, 157, 185], [16, 128, 167], [17, 245, 273], [18, 205, 260], [19, 178, 254], [20, 155, 251]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  317
# Giá trị của đốt ngón đang mở:  339
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  66
# Giá trị của đốt ngón đang mở:  133
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  100
# Giá trị của đốt ngón đang mở:  163
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  167
# Giá trị của đốt ngón đang mở:  210
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  251
# Giá trị của đốt ngón đang mở:  260
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 374, 329], [1, 400, 259], [2, 382, 193], [3, 352, 134], [4, 328, 87], [5, 292, 202], [6, 247, 134], [7, 223, 94], [8, 206, 66], [9, 266, 227], [10, 218, 162], [11, 189, 124], [12, 169, 98], [13, 255, 251], [14, 205, 210], [15, 171, 184], [16, 144, 165], [17, 257, 272], [18, 217, 260], [19, 190, 253], [20, 167, 251]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  328
# Giá trị của đốt ngón đang mở:  352
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  66
# Giá trị của đốt ngón đang mở:  134
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  98
# Giá trị của đốt ngón đang mở:  162
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  165
# Giá trị của đốt ngón đang mở:  210
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  251
# Giá trị của đốt ngón đang mở:  260
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 383, 333], [1, 407, 263], [2, 388, 196], [3, 357, 138], [4, 331, 89], [5, 292, 204], [6, 245, 138], [7, 217, 98], [8, 197, 69], [9, 267, 230], [10, 217, 168], [11, 188, 131], [12, 167, 106], [13, 256, 255], [14, 204, 214], [15, 171, 190], [16, 145, 173], [17, 257, 276], [18, 215, 261], [19, 190, 254], [20, 170, 252]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  331
# Giá trị của đốt ngón đang mở:  357
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  69
# Giá trị của đốt ngón đang mở:  138
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  106
# Giá trị của đốt ngón đang mở:  168
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  173
# Giá trị của đốt ngón đang mở:  214
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  252
# Giá trị của đốt ngón đang mở:  261
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 395, 338], [1, 421, 266], [2, 395, 197], [3, 357, 138], [4, 326, 87], [5, 296, 211], [6, 242, 142], [7, 210, 101], [8, 188, 72], [9, 270, 237], [10, 215, 174], [11, 184, 135], [12, 164, 109], [13, 259, 262], [14, 204, 222], [15, 169, 197], [16, 141, 180], [17, 262, 281], [18, 218, 264], [19, 192, 256], [20, 171, 254]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  326
# Giá trị của đốt ngón đang mở:  357
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  72
# Giá trị của đốt ngón đang mở:  142
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  109
# Giá trị của đốt ngón đang mở:  174
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  180
# Giá trị của đốt ngón đang mở:  222
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  254
# Giá trị của đốt ngón đang mở:  264
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 406, 344], [1, 431, 268], [2, 405, 200], [3, 367, 142], [4, 333, 92], [5, 301, 213], [6, 246, 144], [7, 213, 102], [8, 191, 73], [9, 275, 240], [10, 218, 176], [11, 186, 137], [12, 165, 111], [13, 264, 265], [14, 208, 225], [15, 172, 199], [16, 144, 181], [17, 268, 285], [18, 224, 269], [19, 197, 260], [20, 175, 256]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  333
# Giá trị của đốt ngón đang mở:  367
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  73
# Giá trị của đốt ngón đang mở:  144
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  111
# Giá trị của đốt ngón đang mở:  176
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  181
# Giá trị của đốt ngón đang mở:  225
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  256
# Giá trị của đốt ngón đang mở:  269
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 410, 355], [1, 436, 276], [2, 411, 207], [3, 373, 147], [4, 341, 97], [5, 307, 219], [6, 253, 148], [7, 220, 106], [8, 197, 76], [9, 280, 246], [10, 224, 180], [11, 192, 140], [12, 171, 114], [13, 269, 270], [14, 213, 228], [15, 178, 202], [16, 151, 183], [17, 272, 291], [18, 228, 273], [19, 200, 264], [20, 178, 260]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  341
# Giá trị của đốt ngón đang mở:  373
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  76
# Giá trị của đốt ngón đang mở:  148
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  114
# Giá trị của đốt ngón đang mở:  180
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  183
# Giá trị của đốt ngón đang mở:  228
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  260
# Giá trị của đốt ngón đang mở:  273
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 407, 366], [1, 431, 286], [2, 403, 217], [3, 368, 156], [4, 334, 105], [5, 301, 228], [6, 248, 157], [7, 218, 113], [8, 197, 83], [9, 275, 254], [10, 220, 187], [11, 191, 145], [12, 173, 118], [13, 265, 278], [14, 209, 235], [15, 175, 206], [16, 150, 186], [17, 268, 297], [18, 226, 277], [19, 197, 266], [20, 176, 262]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  334
# Giá trị của đốt ngón đang mở:  368
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  83
# Giá trị của đốt ngón đang mở:  157
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  118
# Giá trị của đốt ngón đang mở:  187
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  186
# Giá trị của đốt ngón đang mở:  235
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  262
# Giá trị của đốt ngón đang mở:  277
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 406, 369], [1, 431, 289], [2, 401, 217], [3, 363, 157], [4, 330, 107], [5, 300, 229], [6, 247, 157], [7, 218, 114], [8, 197, 83], [9, 272, 255], [10, 219, 187], [11, 191, 146], [12, 172, 119], [13, 262, 278], [14, 210, 233], [15, 177, 204], [16, 150, 184], [17, 266, 296], [18, 224, 274], [19, 196, 264], [20, 173, 261]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  330
# Giá trị của đốt ngón đang mở:  363
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  83
# Giá trị của đốt ngón đang mở:  157
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  119
# Giá trị của đốt ngón đang mở:  187
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  184
# Giá trị của đốt ngón đang mở:  233
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  261
# Giá trị của đốt ngón đang mở:  274
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 396, 377], [1, 418, 300], [2, 374, 232], [3, 329, 180], [4, 291, 133], [5, 288, 246], [6, 230, 174], [7, 205, 129], [8, 186, 96], [9, 268, 266], [10, 214, 204], [11, 190, 162], [12, 175, 132], [13, 264, 276], [14, 217, 222], [15, 195, 186], [16, 177, 155], [17, 269, 275], [18, 225, 232], [19, 201, 204], [20, 184, 180]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  291
# Giá trị của đốt ngón đang mở:  329
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  96
# Giá trị của đốt ngón đang mở:  174
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  132
# Giá trị của đốt ngón đang mở:  204
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  155
# Giá trị của đốt ngón đang mở:  222
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  180
# Giá trị của đốt ngón đang mở:  232
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 378, 407], [1, 369, 319], [2, 333, 262], [3, 317, 224], [4, 302, 189], [5, 280, 244], [6, 251, 183], [7, 244, 141], [8, 240, 106], [9, 265, 247], [10, 223, 185], [11, 216, 137], [12, 220, 101], [13, 258, 256], [14, 207, 196], [15, 198, 152], [16, 199, 117], [17, 260, 266], [18, 218, 213], [19, 202, 173], [20, 196, 138]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  302
# Giá trị của đốt ngón đang mở:  317
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  106
# Giá trị của đốt ngón đang mở:  183
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  101
# Giá trị của đốt ngón đang mở:  185
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  117
# Giá trị của đốt ngón đang mở:  196
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  138
# Giá trị của đốt ngón đang mở:  213
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 317, 445], [1, 237, 393], [2, 174, 331], [3, 141, 276], [4, 122, 232], [5, 231, 265], [6, 226, 194], [7, 231, 155], [8, 234, 122], [9, 273, 260], [10, 274, 187], [11, 279, 141], [12, 282, 104], [13, 311, 269], [14, 315, 201], [15, 320, 163], [16, 322, 132], [17, 352, 286], [18, 359, 237], [19, 360, 209], [20, 362, 184]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  122
# Giá trị của đốt ngón đang mở:  141
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  122
# Giá trị của đốt ngón đang mở:  194
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  104
# Giá trị của đốt ngón đang mở:  187
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  132
# Giá trị của đốt ngón đang mở:  201
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  184
# Giá trị của đốt ngón đang mở:  237
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 268, 474], [1, 193, 415], [2, 153, 345], [3, 136, 291], [4, 121, 254], [5, 245, 283], [6, 249, 216], [7, 256, 177], [8, 262, 142], [9, 289, 283], [10, 299, 205], [11, 307, 159], [12, 312, 118], [13, 325, 298], [14, 343, 228], [15, 354, 186], [16, 362, 147], [17, 362, 324], [18, 379, 270], [19, 388, 238], [20, 396, 205]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  121
# Giá trị của đốt ngón đang mở:  136
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  142
# Giá trị của đốt ngón đang mở:  216
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  118
# Giá trị của đốt ngón đang mở:  205
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  147
# Giá trị của đốt ngón đang mở:  228
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  205
# Giá trị của đốt ngón đang mở:  270
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 255, 489], [1, 188, 428], [2, 162, 353], [3, 150, 298], [4, 134, 259], [5, 252, 297], [6, 262, 230], [7, 267, 191], [8, 273, 157], [9, 295, 300], [10, 311, 224], [11, 319, 177], [12, 324, 139], [13, 331, 315], [14, 355, 247], [15, 368, 205], [16, 377, 167], [17, 365, 342], [18, 387, 288], [19, 397, 254], [20, 404, 221]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  134
# Giá trị của đốt ngón đang mở:  150
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  157
# Giá trị của đốt ngón đang mở:  230
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  139
# Giá trị của đốt ngón đang mở:  224
# id:  3
# Ngón___đang mở 3
# Giá trị của ngón đang mở:  167
# Giá trị của đốt ngón đang mở:  247
# id:  4
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  221
# Giá trị của đốt ngón đang mở:  288
# Array fingers is [1, 1, 1, 1, 1]
# Số ngón tay đang mở:  5
# [[0, 237, 485], [1, 180, 423], [2, 163, 343], [3, 157, 287], [4, 140, 253], [5, 257, 296], [6, 272, 230], [7, 279, 192], [8, 287, 158], [9, 300, 303], [10, 322, 229], [11, 333, 182], [12, 340, 144], [13, 333, 323], [14, 365, 253], [15, 380, 210], [16, 390, 171], [17, 363, 353], [18, 391, 301], [19, 404, 265], [20, 415, 230]]
# Ngón___đang mở 4
# Giá trị của ngón đang mở:  140
# Giá trị của đốt ngón đang mở:  157
# id:  1
# ...
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  170
# Giá trị của đốt ngón đang mở:  246
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  187
# Giá trị của đốt ngón đang mở:  262
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 228, 462], [1, 209, 418], [2, 223, 360], [3, 273, 331], [4, 318, 323], [5, 264, 312], [6, 274, 246], [7, 282, 204], [8, 292, 171], [9, 299, 327], [10, 336, 262], [11, 356, 220], [12, 376, 188], [13, 321, 355], [14, 346, 327], [15, 309, 355], [16, 280, 383], [17, 338, 388], [18, 370, 360], [19, 349, 370], [20, 324, 386]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  171
# Giá trị của đốt ngón đang mở:  246
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  188
# Giá trị của đốt ngón đang mở:  262
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 228, 465], [1, 209, 420], [2, 224, 362], [3, 273, 334], [4, 318, 326], [5, 265, 313], [6, 274, 245], [7, 282, 203], [8, 292, 169], [9, 300, 328], [10, 336, 264], [11, 357, 221], [12, 376, 188], [13, 322, 356], [14, 346, 329], [15, 310, 358], [16, 280, 386], [17, 339, 389], [18, 372, 362], [19, 352, 373], [20, 327, 391]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  169
# Giá trị của đốt ngón đang mở:  245
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  188
# Giá trị của đốt ngón đang mở:  264
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 230, 465], [1, 211, 421], [2, 224, 363], [3, 272, 334], [4, 318, 326], [5, 266, 313], [6, 276, 246], [7, 283, 204], [8, 294, 170], [9, 301, 329], [10, 338, 264], [11, 357, 221], [12, 377, 188], [13, 324, 356], [14, 346, 328], [15, 309, 357], [16, 279, 385], [17, 340, 389], [18, 372, 361], [19, 350, 372], [20, 325, 389]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  170
# Giá trị của đốt ngón đang mở:  246
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  188
# Giá trị của đốt ngón đang mở:  264
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 233, 463], [1, 214, 419], [2, 226, 362], [3, 275, 334], [4, 319, 326], [5, 269, 312], [6, 279, 246], [7, 287, 204], [8, 297, 169], [9, 305, 327], [10, 341, 262], [11, 360, 220], [12, 379, 188], [13, 327, 355], [14, 350, 327], [15, 313, 356], [16, 284, 382], [17, 343, 388], [18, 373, 359], [19, 351, 371], [20, 326, 387]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  169
# Giá trị của đốt ngón đang mở:  246
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  188
# Giá trị của đốt ngón đang mở:  262
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 233, 468], [1, 214, 422], [2, 228, 364], [3, 279, 336], [4, 323, 329], [5, 270, 315], [6, 279, 249], [7, 286, 207], [8, 297, 173], [9, 305, 331], [10, 340, 266], [11, 361, 223], [12, 381, 191], [13, 327, 358], [14, 349, 332], [15, 314, 360], [16, 284, 388], [17, 343, 391], [18, 377, 365], [19, 357, 375], [20, 332, 391]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  173
# Giá trị của đốt ngón đang mở:  249
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  191
# Giá trị của đốt ngón đang mở:  266
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 233, 469], [1, 214, 424], [2, 227, 367], [3, 276, 337], [4, 322, 330], [5, 269, 317], [6, 279, 251], [7, 286, 209], [8, 296, 175], [9, 304, 333], [10, 341, 268], [11, 361, 225], [12, 380, 192], [13, 327, 361], [14, 349, 333], [15, 313, 363], [16, 284, 392], [17, 344, 393], [18, 377, 365], [19, 356, 376], [20, 330, 392]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  175
# Giá trị của đốt ngón đang mở:  251
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  192
# Giá trị của đốt ngón đang mở:  268
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 233, 466], [1, 214, 422], [2, 226, 364], [3, 275, 336], [4, 321, 327], [5, 268, 314], [6, 278, 248], [7, 286, 206], [8, 296, 172], [9, 305, 330], [10, 340, 265], [11, 359, 223], [12, 379, 189], [13, 328, 358], [14, 349, 329], [15, 313, 359], [16, 285, 387], [17, 345, 392], [18, 377, 362], [19, 355, 372], [20, 329, 389]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  172
# Giá trị của đốt ngón đang mở:  248
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  189
# Giá trị của đốt ngón đang mở:  265
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 231, 461], [1, 213, 415], [2, 226, 359], [3, 276, 333], [4, 322, 326], [5, 268, 308], [6, 278, 243], [7, 285, 201], [8, 295, 168], [9, 304, 325], [10, 339, 260], [11, 359, 218], [12, 379, 185], [13, 327, 354], [14, 348, 326], [15, 313, 356], [16, 286, 384], [17, 344, 388], [18, 374, 358], [19, 354, 371], [20, 331, 388]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  168
# Giá trị của đốt ngón đang mở:  243
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  185
# Giá trị của đốt ngón đang mở:  260
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 230, 461], [1, 211, 416], [2, 224, 358], [3, 273, 329], [4, 319, 321], [5, 265, 308], [6, 275, 242], [7, 283, 200], [8, 293, 166], [9, 301, 325], [10, 337, 259], [11, 357, 216], [12, 377, 183], [13, 323, 353], [14, 346, 325], [15, 311, 355], [16, 282, 384], [17, 340, 386], [18, 373, 357], [19, 354, 368], [20, 330, 385]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  166
# Giá trị của đốt ngón đang mở:  242
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  183
# Giá trị của đốt ngón đang mở:  259
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 230, 458], [1, 213, 413], [2, 226, 355], [3, 275, 327], [4, 321, 319], [5, 268, 307], [6, 278, 241], [7, 285, 200], [8, 295, 166], [9, 303, 323], [10, 340, 258], [11, 359, 216], [12, 378, 183], [13, 326, 352], [14, 348, 324], [15, 311, 351], [16, 282, 378], [17, 343, 385], [18, 376, 356], [19, 355, 365], [20, 331, 381]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  166
# Giá trị của đốt ngón đang mở:  241
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  183
# Giá trị của đốt ngón đang mở:  258
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 231, 460], [1, 212, 415], [2, 225, 357], [3, 275, 328], [4, 321, 320], [5, 267, 309], [6, 277, 242], [7, 285, 200], [8, 295, 166], [9, 302, 325], [10, 339, 259], [11, 358, 217], [12, 377, 184], [13, 325, 354], [14, 348, 324], [15, 312, 352], [16, 283, 380], [17, 342, 387], [18, 376, 358], [19, 356, 366], [20, 331, 380]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  166
# Giá trị của đốt ngón đang mở:  242
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  184
# Giá trị của đốt ngón đang mở:  259
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 230, 463], [1, 212, 417], [2, 225, 360], [3, 274, 330], [4, 319, 322], [5, 267, 311], [6, 277, 245], [7, 284, 203], [8, 294, 169], [9, 302, 327], [10, 338, 262], [11, 357, 219], [12, 378, 186], [13, 324, 355], [14, 347, 327], [15, 311, 355], [16, 282, 383], [17, 341, 388], [18, 376, 360], [19, 355, 367], [20, 329, 381]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  169
# Giá trị của đốt ngón đang mở:  245
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  186
# Giá trị của đốt ngón đang mở:  262
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 232, 461], [1, 213, 416], [2, 226, 358], [3, 275, 330], [4, 320, 322], [5, 268, 309], [6, 278, 243], [7, 286, 202], [8, 296, 169], [9, 304, 325], [10, 340, 260], [11, 359, 218], [12, 379, 185], [13, 328, 353], [14, 349, 325], [15, 312, 354], [16, 284, 382], [17, 345, 387], [18, 377, 358], [19, 356, 367], [20, 331, 382]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  169
# Giá trị của đốt ngón đang mở:  243
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  185
# Giá trị của đốt ngón đang mở:  260
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 235, 456], [1, 216, 411], [2, 229, 354], [3, 278, 327], [4, 323, 319], [5, 271, 305], [6, 282, 240], [7, 290, 199], [8, 300, 166], [9, 307, 322], [10, 343, 257], [11, 363, 215], [12, 383, 182], [13, 330, 350], [14, 353, 321], [15, 319, 348], [16, 292, 374], [17, 347, 383], [18, 378, 354], [19, 357, 365], [20, 334, 381]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  166
# Giá trị của đốt ngón đang mở:  240
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  182
# Giá trị của đốt ngón đang mở:  257
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 234, 458], [1, 214, 412], [2, 228, 353], [3, 279, 323], [4, 327, 317], [5, 269, 305], [6, 281, 237], [7, 289, 195], [8, 300, 160], [9, 304, 322], [10, 342, 255], [11, 363, 213], [12, 383, 179], [13, 328, 350], [14, 350, 321], [15, 314, 351], [16, 286, 380], [17, 345, 383], [18, 378, 353], [19, 357, 363], [20, 331, 379]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  160
# Giá trị của đốt ngón đang mở:  237
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  179
# Giá trị của đốt ngón đang mở:  255
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 234, 456], [1, 215, 409], [2, 229, 351], [3, 280, 323], [4, 326, 317], [5, 270, 303], [6, 281, 235], [7, 290, 193], [8, 301, 158], [9, 306, 319], [10, 343, 253], [11, 364, 210], [12, 385, 176], [13, 330, 347], [14, 352, 320], [15, 318, 348], [16, 290, 376], [17, 347, 381], [18, 379, 352], [19, 359, 362], [20, 334, 378]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  158
# Giá trị của đốt ngón đang mở:  235
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  176
# Giá trị của đốt ngón đang mở:  253
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 232, 452], [1, 211, 405], [2, 226, 346], [3, 279, 319], [4, 325, 312], [5, 268, 295], [6, 280, 227], [7, 289, 183], [8, 301, 149], [9, 305, 312], [10, 343, 245], [11, 365, 202], [12, 387, 168], [13, 330, 341], [14, 353, 312], [15, 319, 341], [16, 292, 369], [17, 348, 375], [18, 378, 344], [19, 360, 357], [20, 338, 377]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  149
# Giá trị của đốt ngón đang mở:  227
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  168
# Giá trị của đốt ngón đang mở:  245
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 233, 448], [1, 212, 402], [2, 227, 341], [3, 280, 312], [4, 327, 306], [5, 269, 288], [6, 282, 219], [7, 291, 175], [8, 302, 139], [9, 307, 305], [10, 347, 237], [11, 369, 193], [12, 391, 159], [13, 332, 335], [14, 356, 308], [15, 321, 339], [16, 293, 367], [17, 350, 367], [18, 380, 337], [19, 360, 352], [20, 339, 371]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  139
# Giá trị của đốt ngón đang mở:  219
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  159
# Giá trị của đốt ngón đang mở:  237
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 231, 451], [1, 209, 404], [2, 225, 341], [3, 280, 311], [4, 328, 304], [5, 268, 286], [6, 280, 216], [7, 288, 170], [8, 300, 133], [9, 306, 304], [10, 347, 234], [11, 371, 188], [12, 394, 153], [13, 331, 334], [14, 355, 306], [15, 317, 337], [16, 287, 367], [17, 350, 368], [18, 382, 337], [19, 359, 351], [20, 334, 371]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  133
# Giá trị của đốt ngón đang mở:  216
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  153
# Giá trị của đốt ngón đang mở:  234
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 229, 451], [1, 206, 403], [2, 222, 340], [3, 277, 309], [4, 327, 301], [5, 266, 283], [6, 278, 210], [7, 287, 163], [8, 298, 125], [9, 306, 300], [10, 348, 229], [11, 374, 182], [12, 397, 146], [13, 332, 331], [14, 355, 304], [15, 316, 338], [16, 286, 368], [17, 352, 366], [18, 382, 335], [19, 358, 350], [20, 334, 368]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  125
# Giá trị của đốt ngón đang mở:  210
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  146
# Giá trị của đốt ngón đang mở:  229
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 232, 448], [1, 209, 400], [2, 222, 335], [3, 278, 306], [4, 327, 298], [5, 270, 278], [6, 282, 204], [7, 290, 157], [8, 302, 119], [9, 310, 295], [10, 353, 222], [11, 378, 175], [12, 402, 138], [13, 338, 326], [14, 359, 300], [15, 318, 333], [16, 285, 363], [17, 359, 361], [18, 389, 329], [19, 364, 343], [20, 339, 362]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  119
# Giá trị của đốt ngón đang mở:  204
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  138
# Giá trị của đốt ngón đang mở:  222
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 234, 449], [1, 209, 400], [2, 224, 333], [3, 284, 302], [4, 336, 294], [5, 272, 272], [6, 284, 196], [7, 293, 146], [8, 305, 107], [9, 313, 291], [10, 359, 215], [11, 385, 165], [12, 409, 127], [13, 342, 323], [14, 366, 295], [15, 323, 332], [16, 290, 364], [17, 364, 360], [18, 396, 325], [19, 368, 343], [20, 341, 366]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  107
# Giá trị của đốt ngón đang mở:  196
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  127
# Giá trị của đốt ngón đang mở:  215
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 234, 452], [1, 210, 400], [2, 227, 333], [3, 289, 303], [4, 341, 294], [5, 273, 274], [6, 284, 197], [7, 292, 147], [8, 305, 107], [9, 315, 292], [10, 358, 215], [11, 385, 165], [12, 411, 127], [13, 343, 323], [14, 368, 296], [15, 326, 332], [16, 293, 363], [17, 363, 362], [18, 398, 328], [19, 373, 344], [20, 345, 364]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  107
# Giá trị của đốt ngón đang mở:  197
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  127
# Giá trị của đốt ngón đang mở:  215
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 232, 453], [1, 210, 401], [2, 226, 333], [3, 287, 302], [4, 339, 294], [5, 272, 274], [6, 283, 197], [7, 292, 148], [8, 304, 108], [9, 314, 292], [10, 358, 215], [11, 385, 166], [12, 411, 128], [13, 343, 324], [14, 366, 297], [15, 324, 332], [16, 291, 364], [17, 364, 361], [18, 397, 327], [19, 372, 344], [20, 344, 365]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  108
# Giá trị của đốt ngón đang mở:  197
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  128
# Giá trị của đốt ngón đang mở:  215
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# [[0, 252, 474], [1, 208, 436], [2, 210, 372], [3, 276, 335], [4, 340, 328], [5, 264, 273], [6, 279, 170], [7, 291, 105], [8, 304, 51], [9, 323, 293], [10, 378, 195], [11, 417, 132], [12, 452, 77], [13, 366, 330], [14, 401, 306], [15, 350, 353], [16, 308, 389], [17, 396, 379], [18, 426, 352], [19, 391, 385], [20, 355, 418]]
# id:  1
# Ngón___đang mở 1
# Giá trị của ngón đang mở:  51
# Giá trị của đốt ngón đang mở:  170
# id:  2
# Ngón___đang mở 2
# Giá trị của ngón đang mở:  77
# Giá trị của đốt ngón đang mở:  195
# id:  3
# id:  4
# Array fingers is [0, 1, 1, 0, 0]
# Số ngón tay đang mở:  2
# []
# []
# [[0, 236, 207], [1, 285, 240], [2, 320, 293], [3, 338, 338], [4, 352, 372], [5, 288, 319], [6, 294, 380], [7, 297, 413], [8, 299, 437], [9, 250, 324], [10, 258, 383], [11, 262, 418], [12, 263, 447], [13, 212, 325], [14, 217, 387], [15, 222, 422], [16, 224, 452], [17, 174, 322], [18, 170, 374], [19, 172, 409], [20, 177, 440]]
# id:  1
# id:  2
# id:  3
# id:  4
# Array fingers is [0, 0, 0, 0, 0]
# Số ngón tay đang mở:  0
# [[0, 242, 222], [1, 293, 240], [2, 334, 277], [3, 356, 318], [4, 374, 351], [5, 294, 294], [6, 304, 353], [7, 309, 392], [8, 314, 422], [9, 248, 305], [10, 256, 362], [11, 261, 399], [12, 265, 430], [13, 207, 312], [14, 211, 366], [15, 215, 403], [16, 220, 432], [17, 170, 317], [18, 167, 361], [19, 169, 393], [20, 171, 419]]
# id:  1
# id:  2
# id:  3
# id:  4
# Array fingers is [0, 0, 0, 0, 0]
# Số ngón tay đang mở:  0
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
